# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, Sampler
import cv2


cudnn.benchmark = True
plt.ion()

# %%
# !unzip data.zip
# %ls
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/normal/
#   inflating: data/normal/1.jpg
#   inflating: data/normal/10.jpg
#   inflating: data/normal/11.jpg
#   inflating: data/normal/12.png
#   inflating: data/normal/13.png
#   inflating: data/normal/14.jpg
#   inflating: data/normal/15.jpg
#   inflating: data/normal/16.jpg
#   inflating: data/normal/17.jpg
#   inflating: data/normal/18.jpg
#   inflating: data/normal/19.jpg
#   inflating: data/normal/2.jpg
#   inflating: data/normal/20.jpg
#   inflating: data/normal/21.jpg
#   inflating: data/normal/22.jpg
#   inflating: data/normal/23.jpg
#   inflating: data/normal/24.jpg
#   inflating: data/normal/25.jpg
#   inflating: data/normal/26.jpg
#   inflating: data/normal/27.jpg
#   inflating: data/normal/28.jpg
#   inflating: data/normal/29.jpg
#   inflating: data/normal/3.jpg
#   inflating: data/normal/34.jpg
#   inflating: data/normal/35.jpg
#   inflating: data/normal/36.jpg
#   inflating: data/normal/37.jpg
#   inflating: data/normal/38.jpg
#   inflating: data/normal/39.jpg
#   inflating: data/normal/4.png
#   inflating: data/normal/40.jpg
#   inflating: data/normal/41.jpg
#   inflating: data/normal/42.jpg
#   inflating: data/normal/43.jpg
#   inflating: data/normal/44.jpg
#   inflating: data/normal/45.jpg
#   inflating: data/normal/46.jpg
#   inflating: data/normal/47.jpg
#   inflating: data/normal/48.jpg
#   inflating: data/normal/49.jpg
#   inflating: data/normal/5.png
#   inflating: data/normal/50.png
#   inflating: data/normal/6.png
#   inflating: data/normal/7.jpg
#   inflating: data/normal/8.png
#   inflating: data/normal/9.png
#    creating: data/phishing/
#   inflating: data/phishing/1.png
#   inflating: data/phishing/10.png
#   inflating: data/phishing/11.png
#   inflating: data/phishing/12.png
#   inflating: data/phishing/13.png
#   inflating: data/phishing/14.png
#   inflating: data/phishing/15.png
#   inflating: data/phishing/16.png
#   inflating: data/phishing/17.png
#   inflating: data/phishing/18.png
#   inflating: data/phishing/19.png
#   inflating: data/phishing/2.png
#   inflating: data/phishing/20.png
#   inflating: data/phishing/21.png
#   inflating: data/phishing/22.png
#   inflating: data/phishing/23.png
#   inflating: data/phishing/24.jpg
#   inflating: data/phishing/25.jpg
#   inflating: data/phishing/26.jpg
#   inflating: data/phishing/27.jpg
#   inflating: data/phishing/28.jpg
#   inflating: data/phishing/29.jpg
#   inflating: data/phishing/3.png
#   inflating: data/phishing/30.jpg
#   inflating: data/phishing/31.jpg
#   inflating: data/phishing/32.jpg
#   inflating: data/phishing/33.jpg
#   inflating: data/phishing/34.jpg
#   inflating: data/phishing/35.jpg
#   inflating: data/phishing/36.jpg
#   inflating: data/phishing/4.png
#   inflating: data/phishing/5.png
#   inflating: data/phishing/6.png
#   inflating: data/phishing/7.png
#   inflating: data/phishing/8.png
#   inflating: data/phishing/9.png
# data/  data.zip  sample_data/

# %% [markdown]
# Rewrite dataset classes

# %%
class ImageDataset(Dataset):
    def __init__(self, dataset_dir, train=False):
        self.data_transforms = {
                            'train': transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Resize((256, 256)),
                                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                            ]),
                            'val': transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Resize((256, 256)),
                                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                            ]),
                        }
        self.dataset_dir = dataset_dir

        self.labels = []
        self.raw_images = []
        self.train = train

        for dirpath, dirnames, filenames in os.walk(dataset_dir):
            for fn in filenames:
                label = 0 if 'normal' in dirpath else 1
                raw_img = cv2.imread(f'{dirpath}/{fn}')
                self.labels.append(label)
                self.raw_images.append(raw_img)

        self.train_images = [self.data_transforms['train'](img) for img in self.raw_images]
        self.test_images = [self.data_transforms['val'](img) for img in self.raw_images]

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        if self.train:
            return self.train_images[idx], self.labels[idx]
        else:
            return self.test_images[idx], self.labels[idx]

# %%
data_dir = 'data/'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Calculate the number of images in data_directory

# %%
n_images = 0
for dirpath, dirnames, filenames in os.walk(data_dir):
    n_images += len(filenames)

# %%
n_images
# Out:
# 82

# %%
image_idxs = np.arange(n_images)

# %% [markdown]
# Now we can split that indices into groups and

# %% [markdown]
# ~10 sec. to store all images

# %%
dataset = ImageDataset(data_dir)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
from sklearn.model_selection import StratifiedKFold

n_folds = 5
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=47)

# %%
class_names = {0: 'normal', 1: 'phishing'}

# %%
def imshow(inp, title=None):

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)

    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(dataloader))

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x.item()] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    train_losses_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    val_losses_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    train_accs_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    val_accs_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]

    best_model_params_path = os.path.join('.', 'best_model_params.pt')

    torch.save(model.state_dict(), best_model_params_path)
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch: {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for i, (train_index, test_index) in enumerate(skf.split(dataset.raw_images, dataset.labels)):
            test_loader = DataLoader(dataset, batch_size=8, sampler=test_index)
            train_loader = DataLoader(dataset, batch_size=8, sampler=train_index)

            print(f'\tFold: {i}/{n_folds}')
            print('\t' + '-' * 10)

            for phase in ['train', 'val']:
                if phase == 'train':
                    loader = train_loader
                    model.train()
                else:
                    loader = test_loader
                    model.eval()

                running_loss = 0.0
                running_corrects = 0

                for inputs, labels in loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    optimizer.zero_grad()

                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                if phase == 'train':
                    scheduler.step()
                    fold_train_loss = running_loss / len(train_index)
                    fold_train_acc = running_corrects.double() / len(train_index)
                    train_losses_by_folds[epoch][i] = fold_train_loss
                    train_accs_by_folds[epoch][i] = fold_train_acc
                    print(f'\t\ttrain loss: {fold_train_loss}')
                    print(f'\t\ttrain acc: {fold_train_acc}')
                else:
                    fold_val_loss = running_loss / len(test_index)
                    fold_val_acc = running_corrects.double() / len(test_index)
                    val_losses_by_folds[epoch][i] = fold_val_loss
                    val_accs_by_folds[epoch][i] = fold_val_acc
                    print(f'\t\tval loss: {fold_val_loss}')
                    print(f'\t\tval acc: {fold_val_acc}')
                print()

            # mean validation loss
            if val_accs_by_folds[epoch].mean() > best_acc:
                best_acc = val_accs_by_folds[epoch].mean()
                torch.save(model.state_dict(), best_model_params_path)
    print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best mean val Acc: {best_acc:4f}')

    model.load_state_dict(torch.load(best_model_params_path))

    train_losses_by_folds = np.array(train_losses_by_folds)
    val_losses_by_folds = np.array(val_losses_by_folds)
    train_accs_by_folds = np.array(train_accs_by_folds)
    val_accs_by_folds = np.array(val_accs_by_folds)


    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses_by_folds.mean(axis=1), label='Training Loss')
    plt.plot(val_losses_by_folds.mean(axis=1), label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accs_by_folds.mean(axis=1), label='Training Accuracy')
    plt.plot(val_accs_by_folds.mean(axis=1), label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j].item()]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet152(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:01<00:00, 157MB/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch: 0/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.35886167792173534
# 		train acc: 0.9846153846153847
#
# 		val loss: 0.2366663883714115
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.36174224110750053
# 		train acc: 0.9846153846153847
#
# 		val loss: 0.22850713922696955
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.3742871889562318
# 		train acc: 0.9848484848484849
#
# 		val loss: 0.25284789502620697
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.3561823404196537
# 		train acc: 1.0
#
# 		val loss: 0.19048717617988586
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.34757866823312006
# 		train acc: 1.0
#
# 		val loss: 0.25571590662002563
# 		val acc: 0.9375
#
# Epoch: 1/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.3350919003670032
# 		train acc: 1.0
#
# 		val loss: 0.2201730819309459
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.342600744504195
# 		train acc: 0.9846153846153847
#
# 		val loss: 0.21271978669306812
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.35039822125073633
# 		train acc: 0.9848484848484849
#
# 		val loss: 0.23713011294603348
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.3292190143556306
# 		train acc: 1.0
#
# 		val loss: 0.17406565696001053
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.32136462312756164
# 		train acc: 1.0
#
# 		val loss: 0.23794292658567429
# 		val acc: 0.9375
#
# Epoch: 2/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.30995749235153197
# 		train acc: 1.0
#
# 		val loss: 0.20464197327108943
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.31857633957496057
# 		train acc: 0.9846153846153847
#
# 		val loss: 0.1973310682703467
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.3256568226850394
# 		train acc: 0.9848484848484849
#
# 		val loss: 0.22097089141607285
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.3047243103836522
# 		train acc: 1.0
#
# 		val loss: 0.15993402898311615
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.29813655804504047
# 		train acc: 1.0
#
# 		val loss: 0.2219655141234398
# 		val acc: 0.9375
#
# Epoch: 3/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.2872142722973457
# 		train acc: 1.0
#
# 		val loss: 0.18977703767664292
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.2957150789407583
# 		train acc: 0.9846153846153847
#
# 		val loss: 0.18345873233150034
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.30205169997432013
# 		train acc: 1.0
#
# 		val loss: 0.20616066455841064
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.28157783548037213
# 		train acc: 1.0
#
# 		val loss: 0.14687258750200272
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.2763307929942102
# 		train acc: 1.0
#
# 		val loss: 0.20786353945732117
# 		val acc: 0.9375
#
# Epoch: 4/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.2658090671667686
# 		train acc: 1.0
#
# 		val loss: 0.17652188855059006
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.2741577338713866
# 		train acc: 1.0
#
# 		val loss: 0.170791753951241
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.2797345324899211
# 		train acc: 1.0
#
# 		val loss: 0.19240225106477737
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.2599027761907289
# 		train acc: 1.0
#
# 		val loss: 0.13527271151542664
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.25580251532973663
# 		train acc: 1.0
#
# 		val loss: 0.19449377804994583
# 		val acc: 0.9375
#
# Epoch: 5/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.24565780873482043
# 		train acc: 1.0
#
# 		val loss: 0.16442353409879348
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.2537735528670825
# 		train acc: 1.0
#
# 		val loss: 0.15934142645667582
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.25886531761198334
# 		train acc: 1.0
#
# 		val loss: 0.17988165095448494
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.23962328831354776
# 		train acc: 1.0
#
# 		val loss: 0.12491236627101898
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.23656514919165408
# 		train acc: 1.0
#
# 		val loss: 0.18270958960056305
# 		val acc: 0.9375
#
# Epoch: 6/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.22682855266791124
# 		train acc: 1.0
#
# 		val loss: 0.15327791080755346
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.23474811292611636
# 		train acc: 1.0
#
# 		val loss: 0.14838873594999313
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.2393303897344705
# 		train acc: 1.0
#
# 		val loss: 0.16803912818431854
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.2208475208643711
# 		train acc: 1.0
#
# 		val loss: 0.11587656289339066
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.21866101749015576
# 		train acc: 1.0
#
# 		val loss: 0.17221220582723618
# 		val acc: 0.9375
#
# Epoch: 7/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.20938399365315072
# 		train acc: 1.0
#
# 		val loss: 0.14333999156951904
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.2169902056455612
# 		train acc: 1.0
#
# 		val loss: 0.1386529794510673
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.22120217617714044
# 		train acc: 1.0
#
# 		val loss: 0.15762322396039963
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.2034974012411002
# 		train acc: 1.0
#
# 		val loss: 0.10750100761651993
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.20211023566397754
# 		train acc: 1.0
#
# 		val loss: 0.16247624158859253
# 		val acc: 0.9375
#
# Epoch: 8/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.19332177547308116
# 		train acc: 1.0
#
# 		val loss: 0.13412900356685414
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.20054805691425617
# 		train acc: 1.0
#
# 		val loss: 0.12967780320083394
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.2044335836262414
# 		train acc: 1.0
#
# 		val loss: 0.14776208624243736
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.18756354667923666
# 		train acc: 1.0
#
# 		val loss: 0.09994051232933998
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.18689660344159964
# 		train acc: 1.0
#
# 		val loss: 0.15364207699894905
# 		val acc: 0.9375
#
# Epoch: 9/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.1785578842346485
# 		train acc: 1.0
#
# 		val loss: 0.12548028370913336
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.18543264132279616
# 		train acc: 1.0
#
# 		val loss: 0.12133832319694407
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.18904437644012045
# 		train acc: 1.0
#
# 		val loss: 0.13907484710216522
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.17300570236914087
# 		train acc: 1.0
#
# 		val loss: 0.09303763508796692
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.1729026624199116
# 		train acc: 1.0
#
# 		val loss: 0.145331759005785
# 		val acc: 0.9375
#
# Epoch: 10/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.16505163736068285
# 		train acc: 1.0
#
# 		val loss: 0.11812339635456309
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.17157061386566896
# 		train acc: 1.0
#
# 		val loss: 0.1137352020424955
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.17492767039573554
# 		train acc: 1.0
#
# 		val loss: 0.13104736804962158
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.15972170143416434
# 		train acc: 1.0
#
# 		val loss: 0.0868455246090889
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.16009549367608447
# 		train acc: 1.0
#
# 		val loss: 0.1382092796266079
# 		val acc: 0.9375
#
# Epoch: 11/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.15275832804349754
# 		train acc: 1.0
#
# 		val loss: 0.11102537197225235
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.1588958414701315
# 		train acc: 1.0
#
# 		val loss: 0.10708056828554939
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.16202227410041925
# 		train acc: 1.0
#
# 		val loss: 0.12363791093230247
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.14762541448528116
# 		train acc: 1.0
#
# 		val loss: 0.08085311204195023
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.14834998186790582
# 		train acc: 1.0
#
# 		val loss: 0.13129206001758575
# 		val acc: 0.9375
#
# Epoch: 12/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.14153488713961382
# 		train acc: 1.0
#
# 		val loss: 0.10512745555709391
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.1473080506691566
# 		train acc: 1.0
#
# 		val loss: 0.1014628984472331
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.1502063824146083
# 		train acc: 1.0
#
# 		val loss: 0.11721352487802505
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.13663247904994272
# 		train acc: 1.0
#
# 		val loss: 0.07603328675031662
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.13766306819337787
# 		train acc: 1.0
#
# 		val loss: 0.12543830648064613
# 		val acc: 0.9375
#
# Epoch: 13/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.13132291791530756
# 		train acc: 1.0
#
# 		val loss: 0.09943387964192558
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.1367390418281922
# 		train acc: 1.0
#
# 		val loss: 0.0963958269532989
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.13944799373998787
# 		train acc: 1.0
#
# 		val loss: 0.11142442002892494
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.1266617625951767
# 		train acc: 1.0
#
# 		val loss: 0.07149432599544525
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.12794669220844904
# 		train acc: 1.0
#
# 		val loss: 0.1197097972035408
# 		val acc: 0.9375
#
# Epoch: 14/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.12203358755661892
# 		train acc: 1.0
#
# 		val loss: 0.09428190045496997
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.12716970489575313
# 		train acc: 1.0
#
# 		val loss: 0.09161945081808988
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.12964444155945923
# 		train acc: 1.0
#
# 		val loss: 0.10612336173653603
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.11763302981853485
# 		train acc: 1.0
#
# 		val loss: 0.06774722412228584
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.11912967264652252
# 		train acc: 1.0
#
# 		val loss: 0.11472465097904205
# 		val acc: 1.0
#
# Epoch: 15/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.11360929631269895
# 		train acc: 1.0
#
# 		val loss: 0.08944872196982889
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.11846030824459516
# 		train acc: 1.0
#
# 		val loss: 0.08710059939938433
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.12075517552368568
# 		train acc: 1.0
#
# 		val loss: 0.10127951577305794
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.10946011159456137
# 		train acc: 1.0
#
# 		val loss: 0.06416845694184303
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.11110615752863162
# 		train acc: 1.0
#
# 		val loss: 0.11033226922154427
# 		val acc: 1.0
#
# Epoch: 16/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.10595432898172966
# 		train acc: 1.0
#
# 		val loss: 0.0852085886632695
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.11055315945010918
# 		train acc: 1.0
#
# 		val loss: 0.08316121995449066
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.11266869746825912
# 		train acc: 1.0
#
# 		val loss: 0.09678659029304981
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.10204390526720972
# 		train acc: 1.0
#
# 		val loss: 0.06105062551796436
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.10383261593453812
# 		train acc: 1.0
#
# 		val loss: 0.10633885487914085
# 		val acc: 1.0
#
# Epoch: 17/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.09899143083737447
# 		train acc: 1.0
#
# 		val loss: 0.08127787183312808
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.10336257247970654
# 		train acc: 1.0
#
# 		val loss: 0.07962941707057111
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.1053401565912998
# 		train acc: 1.0
#
# 		val loss: 0.09269378334283829
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.09530290080742403
# 		train acc: 1.0
#
# 		val loss: 0.05816417559981346
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.09721372795827461
# 		train acc: 1.0
#
# 		val loss: 0.10223814472556114
# 		val acc: 1.0
#
# Epoch: 18/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.09267039184386913
# 		train acc: 1.0
#
# 		val loss: 0.07771059081834905
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.0968225794342848
# 		train acc: 1.0
#
# 		val loss: 0.07633830913726021
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.09864817322655157
# 		train acc: 1.0
#
# 		val loss: 0.0889061838388443
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.08918112753467126
# 		train acc: 1.0
#
# 		val loss: 0.05571068823337555
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.09119061109694568
# 		train acc: 1.0
#
# 		val loss: 0.09864112362265587
# 		val acc: 1.0
#
# Epoch: 19/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.08690566185575266
# 		train acc: 1.0
#
# 		val loss: 0.07440417391412399
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.09085961740750532
# 		train acc: 1.0
#
# 		val loss: 0.07329410687088966
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.09256962906907905
# 		train acc: 1.0
#
# 		val loss: 0.08550203591585159
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.0836149501529607
# 		train acc: 1.0
#
# 		val loss: 0.053243834525346756
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.08569476877649625
# 		train acc: 1.0
#
# 		val loss: 0.09513258375227451
# 		val acc: 1.0
#
# Epoch: 20/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.08164183841301845
# 		train acc: 1.0
#
# 		val loss: 0.07134322997401743
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.08541879178239749
# 		train acc: 1.0
#
# 		val loss: 0.07049637594643761
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.08701201088049194
# 		train acc: 1.0
#
# 		val loss: 0.08235774002969265
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.07853975959799507
# 		train acc: 1.0
#
# 		val loss: 0.05108652263879776
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.08066553340265245
# 		train acc: 1.0
#
# 		val loss: 0.09196262806653976
# 		val acc: 1.0
#
# Epoch: 21/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.07682658004072997
# 		train acc: 1.0
#
# 		val loss: 0.06849127569619347
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.08043585815108739
# 		train acc: 1.0
#
# 		val loss: 0.06789803592597737
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.08193921060724692
# 		train acc: 1.0
#
# 		val loss: 0.07945479638874531
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.07390343284968173
# 		train acc: 1.0
#
# 		val loss: 0.04901939444243908
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.07607418789782307
# 		train acc: 1.0
#
# 		val loss: 0.08881352841854095
# 		val acc: 1.0
#
# Epoch: 22/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.07242393138316962
# 		train acc: 1.0
#
# 		val loss: 0.06591017368961782
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.07588995763888726
# 		train acc: 1.0
#
# 		val loss: 0.06557276779237915
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.0772895324185039
# 		train acc: 1.0
#
# 		val loss: 0.07676446996629238
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.06966907181071513
# 		train acc: 1.0
#
# 		val loss: 0.04718556068837643
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.07186421537489603
# 		train acc: 1.0
#
# 		val loss: 0.08595405891537666
# 		val acc: 1.0
#
# Epoch: 23/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.06840242817997932
# 		train acc: 1.0
#
# 		val loss: 0.06344957211438347
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.07172157999414663
# 		train acc: 1.0
#
# 		val loss: 0.06330124858547659
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.07303337267402446
# 		train acc: 1.0
#
# 		val loss: 0.07427313551306725
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.0657967132600871
# 		train acc: 1.0
#
# 		val loss: 0.045479901134967804
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.06800379700055628
# 		train acc: 1.0
#
# 		val loss: 0.0832977145910263
# 		val acc: 1.0
#
# Epoch: 24/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.0647091750915234
# 		train acc: 1.0
#
# 		val loss: 0.06119613524745492
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.06789532968631158
# 		train acc: 1.0
#
# 		val loss: 0.061264091116540575
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.06912222786834746
# 		train acc: 1.0
#
# 		val loss: 0.0718615110963583
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.06224267297621929
# 		train acc: 1.0
#
# 		val loss: 0.043977782130241394
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.0644504592725725
# 		train acc: 1.0
#
# 		val loss: 0.08096056617796421
# 		val acc: 1.0
#
# Epoch: 25/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.06131132697829833
# 		train acc: 1.0
#
# 		val loss: 0.05903202733572792
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.06436870957796391
# 		train acc: 1.0
#
# 		val loss: 0.0593089450369863
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.06553448860843976
# 		train acc: 1.0
#
# 		val loss: 0.06971277110278606
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.05897650912855611
# 		train acc: 1.0
#
# 		val loss: 0.042422765865921974
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.061172933797493126
# 		train acc: 1.0
#
# 		val loss: 0.07866909727454185
# 		val acc: 1.0
#
# Epoch: 26/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.05818507688549849
# 		train acc: 1.0
#
# 		val loss: 0.05705931870376363
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.06112930127061331
# 		train acc: 1.0
#
# 		val loss: 0.057557839023716306
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.06222456388852813
# 		train acc: 1.0
#
# 		val loss: 0.06753028556704521
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.05596836283802986
# 		train acc: 1.0
#
# 		val loss: 0.041131675243377686
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.05814693179545981
# 		train acc: 1.0
#
# 		val loss: 0.07653531990945339
# 		val acc: 1.0
#
# Epoch: 27/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.055299600614951205
# 		train acc: 1.0
#
# 		val loss: 0.05518900646882899
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.05813844989125545
# 		train acc: 1.0
#
# 		val loss: 0.05586980370914235
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.059171894706334126
# 		train acc: 1.0
#
# 		val loss: 0.06565805338323116
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.05319883279276617
# 		train acc: 1.0
#
# 		val loss: 0.03990417905151844
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.05535495952900612
# 		train acc: 1.0
#
# 		val loss: 0.07456832565367222
# 		val acc: 1.0
#
# Epoch: 28/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.052631199761078905
# 		train acc: 1.0
#
# 		val loss: 0.053461673505166
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.055376032166756115
# 		train acc: 1.0
#
# 		val loss: 0.05433536364751704
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.05634909165515141
# 		train acc: 1.0
#
# 		val loss: 0.06377187184989452
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.050637428959210716
# 		train acc: 1.0
#
# 		val loss: 0.03875384293496609
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.052768236421274414
# 		train acc: 1.0
#
# 		val loss: 0.0726512223482132
# 		val acc: 1.0
#
# Epoch: 29/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.05016075441470513
# 		train acc: 1.0
#
# 		val loss: 0.05184992534272811
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.05281366330499832
# 		train acc: 1.0
#
# 		val loss: 0.05292470139615676
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.05373481342173887
# 		train acc: 1.0
#
# 		val loss: 0.06217028200626373
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.048269688857324196
# 		train acc: 1.0
#
# 		val loss: 0.03764072805643082
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.05036802194786794
# 		train acc: 1.0
#
# 		val loss: 0.07087232917547226
# 		val acc: 1.0
#
#
# Training complete in 5m 35s
# Best mean val Acc: 1.000000

# %%
visualize_model(model_ft)

# %%
model_conv = torchvision.models.resnet152(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)


exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch: 0/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 1.42327497280561
# 		train acc: 0.5076923076923077
#
# 		val loss: 1.198326546479674
# 		val acc: 0.4117647058823529
#
# 	Fold: 1/5
# 	----------
# 		train loss: 2.1058396192697377
# 		train acc: 0.046153846153846156
#
# 		val loss: 0.5965703024583704
# 		val acc: 0.7058823529411764
#
# 	Fold: 2/5
# 	----------
# 		train loss: 1.1504063606262207
# 		train acc: 0.2272727272727273
#
# 		val loss: 0.9690182209014893
# 		val acc: 0.4375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 1.8676690549561472
# 		train acc: 0.10606060606060606
#
# 		val loss: 0.4921773076057434
# 		val acc: 0.625
#
# 	Fold: 4/5
# 	----------
# 		train loss: 1.3039960626399878
# 		train acc: 0.13636363636363635
#
# 		val loss: 0.6404245868325233
# 		val acc: 0.4375
#
# Epoch: 1/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 1.5465165853500367
# 		train acc: 0.12307692307692308
#
# 		val loss: 0.5701670147040311
# 		val acc: 0.6470588235294118
#
# 	Fold: 1/5
# 	----------
# 		train loss: 1.4726593200977032
# 		train acc: 0.12307692307692308
#
# 		val loss: 0.47840746798936057
# 		val acc: 0.8235294117647058
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.8179272106199553
# 		train acc: 0.5
#
# 		val loss: 0.41317400336265564
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.7640603004079877
# 		train acc: 0.3484848484848485
#
# 		val loss: 0.30730973184108734
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6642513744758837
# 		train acc: 0.5303030303030303
#
# 		val loss: 0.3475934714078903
# 		val acc: 0.9375
#
# Epoch: 2/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.608181487596952
# 		train acc: 0.6615384615384616
#
# 		val loss: 0.36170534526600556
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.6242263583036569
# 		train acc: 0.6000000000000001
#
# 		val loss: 0.3765854143044528
# 		val acc: 0.9411764705882353
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.6506878534952799
# 		train acc: 0.5909090909090909
#
# 		val loss: 0.3541318476200104
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6575171459804882
# 		train acc: 0.5606060606060607
#
# 		val loss: 0.31145451962947845
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6078007618586222
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34643128514289856
# 		val acc: 1.0
#
# Epoch: 3/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.6028813462990981
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.35819912833326
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.6031560824467586
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3713376504533431
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.6026631973006509
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.3494631499052048
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6116766749006329
# 		train acc: 0.6212121212121212
#
# 		val loss: 0.3107710927724838
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6068314494508685
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.3455906808376312
# 		val acc: 1.0
#
# Epoch: 4/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.6018896396343525
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.35722222573616924
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5992376355024485
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3709174385842155
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5986936309120872
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34897445142269135
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6077992338122744
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.3105676621198654
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6031440496444702
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.3454939126968384
# 		val acc: 1.0
#
# Epoch: 5/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.598925440128033
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3571375538321102
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5991638018534734
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.37086979957187877
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5986170768737793
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.3489059656858444
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.607396328088009
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31053081154823303
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.602753454988653
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34546178579330444
# 		val acc: 1.0
#
# Epoch: 6/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.598602438890017
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3571046117474051
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5988434598996089
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.37085678910507874
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982841885451115
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889911115169525
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073874957633741
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.3105253726243973
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027450164159139
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545430541038513
# 		val acc: 1.0
#
# Epoch: 7/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985657481046823
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570959532962126
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5988062730202308
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.37085356256541085
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982461318825231
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.3488951176404953
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073497822790435
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052251160144806
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.602708511280291
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545351564884186
# 		val acc: 1.0
#
# Epoch: 8/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985649925011854
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.35709506097961874
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5988054449741657
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982420914100878
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889455139636993
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073457616748232
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052231788635254
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027046478155887
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.3454533666372299
# 		val acc: 1.0
#
# Epoch: 9/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985617821033185
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949294987847
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5988022932639488
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708529858028187
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982420534798594
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889452159404755
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073457381942056
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.3454533517360687
# 		val acc: 1.0
#
# Epoch: 10/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616042063786
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.5988021208689763
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.598241843960502
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889449179172516
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455196438413
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 11/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616005384005
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.35709492073339577
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 12/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.35709492073339577
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 13/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 14/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 15/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 16/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 17/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 18/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 19/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 20/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 21/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 22/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 23/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 24/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 25/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 26/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 27/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 28/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
# Epoch: 29/29
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.5985616078743567
# 		train acc: 0.6923076923076923
#
# 		val loss: 0.3570949154741624
# 		val acc: 0.9411764705882353
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.59880211353302
# 		train acc: 0.6461538461538462
#
# 		val loss: 0.3708530138520634
# 		val acc: 0.8823529411764706
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.5982418331232938
# 		train acc: 0.6666666666666667
#
# 		val loss: 0.34889450669288635
# 		val acc: 0.9375
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.6073455340934523
# 		train acc: 0.6515151515151515
#
# 		val loss: 0.31052227318286896
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.6027043841101907
# 		train acc: 0.6818181818181819
#
# 		val loss: 0.34545333683490753
# 		val acc: 1.0
#
#
# Training complete in 2m 17s
# Best mean val Acc: 0.976471

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    #img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
#visualize_model_predictions(
#    model_conv,
#    img_path='/content/data/normal/1.jpg'
#)

#plt.ioff()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-abaa16e4c490> in <cell line: 1>()
# ----> 1 visualize_model_predictions(
#       2     model_conv,
#       3     img_path='/content/data/normal/1.jpg'
#       4 )
#       5
#
# <ipython-input-33-b3ba80b4fddd> in visualize_model_predictions(model, img_path)
#       4
#       5     img = Image.open(img_path)
# ----> 6     img = data_transforms['val'](img)
#       7     img = img.unsqueeze(0)
#       8     img = img.to(device)
#
# NameError: name 'data_transforms' is not defined
