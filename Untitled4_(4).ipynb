# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, Sampler
import cv2


cudnn.benchmark = True
plt.ion()

# %%
# !unzip data.zip
# %ls
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/normal/
#   inflating: data/normal/1.jpg
#   inflating: data/normal/10.jpg
#   inflating: data/normal/11.jpg
#   inflating: data/normal/12.png
#   inflating: data/normal/13.png
#   inflating: data/normal/14.jpg
#   inflating: data/normal/15.jpg
#   inflating: data/normal/16.jpg
#   inflating: data/normal/17.jpg
#   inflating: data/normal/18.jpg
#   inflating: data/normal/19.jpg
#   inflating: data/normal/2.jpg
#   inflating: data/normal/20.jpg
#   inflating: data/normal/21.jpg
#   inflating: data/normal/22.jpg
#   inflating: data/normal/23.jpg
#   inflating: data/normal/24.jpg
#   inflating: data/normal/25.jpg
#   inflating: data/normal/26.jpg
#   inflating: data/normal/27.jpg
#   inflating: data/normal/28.jpg
#   inflating: data/normal/29.jpg
#   inflating: data/normal/3.jpg
#   inflating: data/normal/34.jpg
#   inflating: data/normal/35.jpg
#   inflating: data/normal/36.jpg
#   inflating: data/normal/37.jpg
#   inflating: data/normal/38.jpg
#   inflating: data/normal/39.jpg
#   inflating: data/normal/4.png
#   inflating: data/normal/40.jpg
#   inflating: data/normal/41.jpg
#   inflating: data/normal/42.jpg
#   inflating: data/normal/43.jpg
#   inflating: data/normal/44.jpg
#   inflating: data/normal/45.jpg
#   inflating: data/normal/46.jpg
#   inflating: data/normal/47.jpg
#   inflating: data/normal/5.png
#   inflating: data/normal/6.png
#   inflating: data/normal/7.jpg
#   inflating: data/normal/8.png
#   inflating: data/normal/9.png
#    creating: data/phishing/
#   inflating: data/phishing/1.png
#   inflating: data/phishing/10.png
#   inflating: data/phishing/11.png
#   inflating: data/phishing/12.png
#   inflating: data/phishing/13.png
#   inflating: data/phishing/14.png
#   inflating: data/phishing/15.png
#   inflating: data/phishing/16.png
#   inflating: data/phishing/17.png
#   inflating: data/phishing/18.png
#   inflating: data/phishing/19.png
#   inflating: data/phishing/2.png
#   inflating: data/phishing/20.png
#   inflating: data/phishing/21.png
#   inflating: data/phishing/22.png
#   inflating: data/phishing/23.png
#   inflating: data/phishing/24.jpg
#   inflating: data/phishing/25.jpg
#   inflating: data/phishing/26.jpg
#   inflating: data/phishing/27.jpg
#   inflating: data/phishing/28.jpg
#   inflating: data/phishing/29.jpg
#   inflating: data/phishing/3.png
#   inflating: data/phishing/30.jpg
#   inflating: data/phishing/31.jpg
#   inflating: data/phishing/32.jpg
#   inflating: data/phishing/33.jpg
#   inflating: data/phishing/34.jpg
#   inflating: data/phishing/35.jpg
#   inflating: data/phishing/36.jpg
#   inflating: data/phishing/4.png
#   inflating: data/phishing/5.png
#   inflating: data/phishing/6.png
#   inflating: data/phishing/7.png
#   inflating: data/phishing/8.png
#   inflating: data/phishing/9.png
# data/  data.zip  sample_data/

# %% [markdown]
# Rewrite dataset classes

# %%
class ImageDataset(Dataset):
    def __init__(self, dataset_dir, train=False):
        self.data_transforms = {
                            'train': transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Resize((256, 256)),
                                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                            ]),
                            'val': transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Resize((256, 256)),
                                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                            ]),
                        }
        self.dataset_dir = dataset_dir

        # read raw image data
        self.labels = []
        self.raw_images = []
        self.train = train

        for dirpath, dirnames, filenames in os.walk(dataset_dir):
            for fn in filenames:
                label = 0 if 'normal' in dirpath else 1
                raw_img = cv2.imread(f'{dirpath}/{fn}')
                self.labels.append(label)
                self.raw_images.append(raw_img)

        # we don't have randomization in out transform, hence, we may apply then
        # directly during initialization (otherwise we should do it during runtime)
        # moreover we create global dataset with all type of images
        self.train_images = [self.data_transforms['train'](img) for img in self.raw_images]
        self.test_images = [self.data_transforms['val'](img) for img in self.raw_images]

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        if self.train:
            return self.train_images[idx], self.labels[idx]
        else:
            return self.test_images[idx], self.labels[idx]

# %%
data_dir = 'data/'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Calculate the number of images in data_directory

# %%
n_images = 0
for dirpath, dirnames, filenames in os.walk(data_dir):
    n_images += len(filenames)

# %%
n_images
# Out:
# 79

# %%
image_idxs = np.arange(n_images)

# %% [markdown]
# Now we can split that indices into groups and

# %% [markdown]
# ~10 sec. to store all images

# %%
dataset = ImageDataset(data_dir)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
from sklearn.model_selection import StratifiedKFold

n_folds = 5
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=47)

# %%
class_names = {0: 'normal', 1: 'phishing'}

# %%
def imshow(inp, title=None):

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)

    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(dataloader))

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x.item()] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    train_losses_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    val_losses_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    train_accs_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]
    val_accs_by_folds = [np.zeros(n_folds) for i in range(num_epochs)]

    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch: {epoch}/{num_epochs - 1}')
            print('-' * 10)

            for i, (train_index, test_index) in enumerate(skf.split(dataset.raw_images, dataset.labels)):
                # make two loaders (test and train)
                test_loader = DataLoader(dataset, batch_size=8, sampler=test_index)
                train_loader = DataLoader(dataset, batch_size=8, sampler=train_index)

                print(f'\tFold: {i}/{n_folds}')
                print('\t' + '-' * 10)

                for phase in ['train', 'val']:
                    if phase == 'train':
                        loader = train_loader
                        model.train()
                    else:
                        loader = test_loader
                        model.eval()

                    running_loss = 0.0
                    running_corrects = 0

                    for inputs, labels in loader:
                        inputs = inputs.to(device)
                        labels = labels.to(device)

                        optimizer.zero_grad()

                        with torch.set_grad_enabled(phase == 'train'):
                            outputs = model(inputs)
                            _, preds = torch.max(outputs, 1)
                            loss = criterion(outputs, labels)

                            if phase == 'train':
                                loss.backward()
                                optimizer.step()

                        running_loss += loss.item() * inputs.size(0)
                        running_corrects += torch.sum(preds == labels.data)

                    if phase == 'train':
                        scheduler.step()
                        fold_train_loss = running_loss / len(train_index)
                        fold_train_acc = running_corrects.double() / len(train_index)
                        train_losses_by_folds[epoch][i] = fold_train_loss
                        train_accs_by_folds[epoch][i] = fold_train_acc
                        print(f'\t\ttrain loss: {fold_train_loss}')
                        print(f'\t\ttrain acc: {fold_train_acc}')
                    else:
                        fold_val_loss = running_loss / len(test_index)
                        fold_val_acc = running_corrects.double() / len(test_index)
                        val_losses_by_folds[epoch][i] = fold_val_loss
                        val_accs_by_folds[epoch][i] = fold_val_acc
                        print(f'\t\tval loss: {fold_val_loss}')
                        print(f'\t\tval acc: {fold_val_acc}')
                    print()

                # mean validation loss
                if val_accs_by_folds[epoch].mean() > best_acc:
                    best_acc = val_accs_by_folds[epoch].mean()
                    torch.save(model.state_dict(), best_model_params_path)
    print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best mean val Acc: {best_acc:4f}')

    model.load_state_dict(torch.load(best_model_params_path))


    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accs, label='Training Accuracy')
    plt.plot(val_accs, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j].item()]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet152(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=2)
# Out:
# Epoch: 0/1
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 1.2829508686822557
# 		train acc: 0.5238095238095237
#
# 		val loss: 0.839395210146904
# 		val acc: 0.4375
#
# 	Fold: 1/5
# 	----------
# 		train loss: 1.4747755735639543
# 		train acc: 0.1111111111111111
#
# 		val loss: 0.6105366349220276
# 		val acc: 0.625
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.9529912008179559
# 		train acc: 0.31746031746031744
#
# 		val loss: 0.5969807654619217
# 		val acc: 0.5625
#
# 	Fold: 3/5
# 	----------
# 		train loss: 1.2056390425515553
# 		train acc: 0.1111111111111111
#
# 		val loss: 0.36911776661872864
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.7480972483754158
# 		train acc: 0.4375
#
# 		val loss: 0.31113325456778207
# 		val acc: 1.0
#
# Epoch: 1/1
# ----------
# 	Fold: 0/5
# 	----------
# 		train loss: 0.8893040475391206
# 		train acc: 0.25396825396825395
#
# 		val loss: 0.22817131876945496
# 		val acc: 1.0
#
# 	Fold: 1/5
# 	----------
# 		train loss: 0.6097899183394417
# 		train acc: 0.6984126984126984
#
# 		val loss: 0.275629386305809
# 		val acc: 1.0
#
# 	Fold: 2/5
# 	----------
# 		train loss: 0.47433929925873164
# 		train acc: 0.9206349206349206
#
# 		val loss: 0.24495940655469894
# 		val acc: 1.0
#
# 	Fold: 3/5
# 	----------
# 		train loss: 0.4523946652336726
# 		train acc: 0.9365079365079365
#
# 		val loss: 0.24422825872898102
# 		val acc: 1.0
#
# 	Fold: 4/5
# 	----------
# 		train loss: 0.41889129392802715
# 		train acc: 0.96875
#
# 		val loss: 0.21348429719607034
# 		val acc: 1.0
#
#
# Training complete in 0m 31s
# Best mean val Acc: 1.000000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-5bc21fdf4875> in <cell line: 1>()
# ----> 1 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=2)
#
# <ipython-input-33-3d0004244a72> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      81     print(f'Best mean val Acc: {best_acc:4f}')
#      82
# ---> 83     model.load_state_dict(torch.load(best_model_params_path))
#      84
#      85
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     996         pickle_load_args['encoding'] = 'utf-8'
#     997
# --> 998     with _open_file_like(f, 'rb') as opened_file:
#     999         if _is_zipfile(opened_file):
#    1000             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     424 class _open_file(_opener):
#     425     def __init__(self, name, mode):
# --> 426         super().__init__(open(name, mode))
#     427
#     428     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpw_5dzhc3/best_model_params.pt'

# %%
visualize_model(model_ft)

# %%
model_conv = torchvision.models.resnet152(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)


exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 19.5386 Acc: 0.7188
# val Loss: 7.4355 Acc: 0.8125
#
# Epoch 1/29
# ----------
# train Loss: 15.1601 Acc: 0.8125
# val Loss: 5.4033 Acc: 0.8125
#
# Epoch 2/29
# ----------
# train Loss: 12.0673 Acc: 0.8125
# val Loss: 4.3496 Acc: 0.8750
#
# Epoch 3/29
# ----------
# train Loss: 7.7752 Acc: 0.9062
# val Loss: 3.4683 Acc: 0.8750
#
# Epoch 4/29
# ----------
# train Loss: 12.7233 Acc: 0.7500
# val Loss: 2.2672 Acc: 1.0000
#
# Epoch 5/29
# ----------
# train Loss: 8.0122 Acc: 0.9062
# val Loss: 4.4691 Acc: 0.8125
#
# Epoch 6/29
# ----------
# train Loss: 5.3232 Acc: 0.9375
# val Loss: 2.0823 Acc: 1.0000
#
# Epoch 7/29
# ----------
# train Loss: 9.9521 Acc: 0.8438
# val Loss: 1.8454 Acc: 1.0000
#
# Epoch 8/29
# ----------
# train Loss: 4.5632 Acc: 0.9688
# val Loss: 1.7674 Acc: 1.0000
#
# Epoch 9/29
# ----------
# train Loss: 8.3630 Acc: 0.8750
# val Loss: 3.4229 Acc: 0.8750
#
# Epoch 10/29
# ----------
# train Loss: 7.6328 Acc: 0.8750
# val Loss: 3.2018 Acc: 0.8125
#
# Epoch 11/29
# ----------
# train Loss: 5.9164 Acc: 0.9375
# val Loss: 3.6037 Acc: 0.8125
#
# Epoch 12/29
# ----------
# train Loss: 6.9942 Acc: 0.9062
# val Loss: 2.2033 Acc: 1.0000
#
# Epoch 13/29
# ----------
# train Loss: 4.1259 Acc: 0.9688
# val Loss: 1.9272 Acc: 1.0000
#
# Epoch 14/29
# ----------
# train Loss: 5.2824 Acc: 0.9688
# val Loss: 2.7152 Acc: 0.8750
#
# Epoch 15/29
# ----------
# train Loss: 4.1461 Acc: 1.0000
# val Loss: 2.4719 Acc: 0.9375
#
# Epoch 16/29
# ----------
# train Loss: 8.6131 Acc: 0.8750
# val Loss: 2.6828 Acc: 0.8750
#
# Epoch 17/29
# ----------
# train Loss: 6.1818 Acc: 0.9688
# val Loss: 1.8152 Acc: 1.0000
#
# Epoch 18/29
# ----------
# train Loss: 11.7908 Acc: 0.8125
# val Loss: 1.8308 Acc: 1.0000
#
# Epoch 19/29
# ----------
# train Loss: 7.5515 Acc: 0.9375
# val Loss: 2.1884 Acc: 1.0000
#
# Epoch 20/29
# ----------
# train Loss: 15.8672 Acc: 0.7500
# val Loss: 2.8159 Acc: 0.8750
#
# Epoch 21/29
# ----------
# train Loss: 5.0051 Acc: 0.9375
# val Loss: 1.9677 Acc: 1.0000
#
# Epoch 22/29
# ----------
# train Loss: 4.4153 Acc: 0.9688
# val Loss: 2.7468 Acc: 0.8750
#
# Epoch 23/29
# ----------
# train Loss: 3.4394 Acc: 1.0000
# val Loss: 2.6421 Acc: 0.8750
#
# Epoch 24/29
# ----------
# train Loss: 5.3588 Acc: 0.9688
# val Loss: 1.9838 Acc: 1.0000
#
# Epoch 25/29
# ----------
# train Loss: 4.6702 Acc: 0.9688
# val Loss: 1.9944 Acc: 1.0000
#
# Epoch 26/29
# ----------
# train Loss: 6.8093 Acc: 0.9375
# val Loss: 3.6425 Acc: 0.8125
#
# Epoch 27/29
# ----------
# train Loss: 9.4010 Acc: 0.8750
# val Loss: 2.8744 Acc: 0.8750
#
# Epoch 28/29
# ----------
# train Loss: 6.1112 Acc: 0.9062
# val Loss: 2.1074 Acc: 1.0000
#
# Epoch 29/29
# ----------
# train Loss: 12.0997 Acc: 0.8438
# val Loss: 2.4563 Acc: 1.0000
#
# Training complete in 19m 30s
# Best val Acc: 1.000000

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
visualize_model_predictions(
    model_conv,
    img_path='/content/data/train/normal/1.jpg'
)

plt.ioff()
plt.show()
