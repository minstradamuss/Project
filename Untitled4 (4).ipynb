# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import matplotlib.pyplot as plt


cudnn.benchmark = True
plt.ion()

# %%
# !unzip data.zip
# %ls
# Out:
# Archive:  data.zip
# replace data/train/normal/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: А
# error:  invalid response [А]
# replace data/train/normal/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/train/normal/1.jpg
#   inflating: data/train/normal/2.jpg
#   inflating: data/train/normal/3.jpg
#   inflating: data/train/normal/4.png
#   inflating: data/train/normal/5.png
#   inflating: data/train/normal/6.png
#   inflating: data/train/normal/7.jpg
#   inflating: data/train/normal/8.png
#   inflating: data/train/normal/9.png
#   inflating: data/train/phishing/1.png
#   inflating: data/train/phishing/10.png
#   inflating: data/train/phishing/11.png
#   inflating: data/train/phishing/12.png
#   inflating: data/train/phishing/13.png
#   inflating: data/train/phishing/14.png
#   inflating: data/train/phishing/15.png
#   inflating: data/train/phishing/16.png
#   inflating: data/train/phishing/17.png
#   inflating: data/train/phishing/18.png
#   inflating: data/train/phishing/19.png
#   inflating: data/train/phishing/2.png
#   inflating: data/train/phishing/20.png
#   inflating: data/train/phishing/21.png
#   inflating: data/train/phishing/22.png
#   inflating: data/train/phishing/23.png
#   inflating: data/train/phishing/3.png
#   inflating: data/train/phishing/4.png
#   inflating: data/train/phishing/5.png
#   inflating: data/train/phishing/6.png
#   inflating: data/train/phishing/7.png
#   inflating: data/train/phishing/8.png
#   inflating: data/train/phishing/9.png
#   inflating: data/val/normal/1.jpg
#   inflating: data/val/normal/2.jpg
#   inflating: data/val/normal/3.png
#   inflating: data/val/normal/4.png
#   inflating: data/val/phishing/1.jpg
#   inflating: data/val/phishing/10.jpg
#   inflating: data/val/phishing/11.jpg
#   inflating: data/val/phishing/12.jpg
#   inflating: data/val/phishing/2.jpg
#   inflating: data/val/phishing/3.jpg
#   inflating: data/val/phishing/4.jpg
#   inflating: data/val/phishing/5.jpg
#   inflating: data/val/phishing/6.jpg
#   inflating: data/val/phishing/7.jpg
#   inflating: data/val/phishing/8.jpg
#   inflating: data/val/phishing/9.jpg
# data/  data.zip  sample_data/

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)

    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(dataloaders['train']))

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            epoch_train_loss = 0.0
            epoch_train_corrects = 0
            epoch_val_loss = 0.0
            epoch_val_corrects = 0

            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()

                running_loss = 0.0
                running_corrects = 0

                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    optimizer.zero_grad()

                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                if phase == 'train':
                    scheduler.step()

                    epoch_train_loss = running_loss / dataset_sizes['train']
                    epoch_train_acc = running_corrects.double() / dataset_sizes['train']
                    train_losses.append(epoch_train_loss)
                    train_accs.append(epoch_train_acc)

                else:
                    epoch_val_loss = running_loss / dataset_sizes['val']
                    epoch_val_acc = running_corrects.double() / dataset_sizes['val']
                    val_losses.append(epoch_val_loss)
                    val_accs.append(epoch_val_acc)

                print(f'{phase} Loss: {running_loss:.4f} Acc: {running_corrects.double() / dataset_sizes[phase]:.4f}')

                if phase == 'val' and epoch_val_acc > best_acc:
                    best_acc = epoch_val_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        model.load_state_dict(torch.load(best_model_params_path))


    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accs, label='Training Accuracy')
    plt.plot(val_accs, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet152(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 21.6942 Acc: 0.6250
# val Loss: 6.0632 Acc: 0.7500
#
# Epoch 1/29
# ----------
# train Loss: 18.7425 Acc: 0.6250
# val Loss: 4.8843 Acc: 0.8125
#
# Epoch 2/29
# ----------
# train Loss: 10.4772 Acc: 0.8125
# val Loss: 3.0691 Acc: 0.8750
#
# Epoch 3/29
# ----------
# train Loss: 7.4572 Acc: 0.9062
# val Loss: 2.6029 Acc: 0.8750
#
# Epoch 4/29
# ----------
# train Loss: 6.3163 Acc: 0.9688
# val Loss: 0.7454 Acc: 1.0000
#
# Epoch 5/29
# ----------
# train Loss: 1.0534 Acc: 1.0000
# val Loss: 0.3463 Acc: 1.0000
#
# Epoch 6/29
# ----------
# train Loss: 1.9568 Acc: 0.9688
# val Loss: 0.1414 Acc: 1.0000
#
# Epoch 7/29
# ----------
# train Loss: 4.1003 Acc: 0.9062
# val Loss: 0.1052 Acc: 1.0000
#
# Epoch 8/29
# ----------
# train Loss: 1.5117 Acc: 1.0000
# val Loss: 0.0763 Acc: 1.0000
#
# Epoch 9/29
# ----------
# train Loss: 3.1718 Acc: 0.9375
# val Loss: 0.0671 Acc: 1.0000
#
# Epoch 10/29
# ----------
# train Loss: 0.5099 Acc: 1.0000
# val Loss: 0.0598 Acc: 1.0000
#
# Epoch 11/29
# ----------
# train Loss: 0.2470 Acc: 1.0000
# val Loss: 0.0558 Acc: 1.0000
#
# Epoch 12/29
# ----------
# train Loss: 2.0841 Acc: 0.9688
# val Loss: 0.0519 Acc: 1.0000
#
# Epoch 13/29
# ----------
# train Loss: 0.5869 Acc: 1.0000
# val Loss: 0.0517 Acc: 1.0000
#
# Epoch 14/29
# ----------
# train Loss: 3.5182 Acc: 0.9375
# val Loss: 0.0524 Acc: 1.0000
#
# Epoch 15/29
# ----------
# train Loss: 1.4289 Acc: 1.0000
# val Loss: 0.0469 Acc: 1.0000
#
# Epoch 16/29
# ----------
# train Loss: 0.5173 Acc: 1.0000
# val Loss: 0.0452 Acc: 1.0000
#
# Epoch 17/29
# ----------
# train Loss: 0.3791 Acc: 1.0000
# val Loss: 0.0485 Acc: 1.0000
#
# Epoch 18/29
# ----------
# train Loss: 0.2664 Acc: 1.0000
# val Loss: 0.0570 Acc: 1.0000
#
# Epoch 19/29
# ----------
# train Loss: 0.2532 Acc: 1.0000
# val Loss: 0.0494 Acc: 1.0000
#
# Epoch 20/29
# ----------
# train Loss: 1.8786 Acc: 0.9688
# val Loss: 0.0495 Acc: 1.0000
#
# Epoch 21/29
# ----------
# train Loss: 0.4200 Acc: 1.0000
# val Loss: 0.0544 Acc: 1.0000
#
# Epoch 22/29
# ----------
# train Loss: 0.7712 Acc: 1.0000
# val Loss: 0.0491 Acc: 1.0000
#
# Epoch 23/29
# ----------
# train Loss: 0.2642 Acc: 1.0000
# val Loss: 0.0526 Acc: 1.0000
#
# Epoch 24/29
# ----------
# train Loss: 0.7081 Acc: 1.0000
# val Loss: 0.0562 Acc: 1.0000
#
# Epoch 25/29
# ----------
# train Loss: 1.2354 Acc: 1.0000
# val Loss: 0.0508 Acc: 1.0000
#
# Epoch 26/29
# ----------
# train Loss: 0.6588 Acc: 1.0000
# val Loss: 0.0525 Acc: 1.0000
#
# Epoch 27/29
# ----------
# train Loss: 0.7436 Acc: 1.0000
# val Loss: 0.0597 Acc: 1.0000
#
# Epoch 28/29
# ----------
# train Loss: 0.7571 Acc: 1.0000
# val Loss: 0.0536 Acc: 1.0000
#
# Epoch 29/29
# ----------
# train Loss: 0.5084 Acc: 1.0000
# val Loss: 0.0501 Acc: 1.0000
#
# Training complete in 44m 22s
# Best val Acc: 1.000000

# %%
visualize_model(model_ft)

# %%
model_conv = torchvision.models.resnet152(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)


exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 19.5386 Acc: 0.7188
# val Loss: 7.4355 Acc: 0.8125
#
# Epoch 1/29
# ----------
# train Loss: 15.1601 Acc: 0.8125
# val Loss: 5.4033 Acc: 0.8125
#
# Epoch 2/29
# ----------
# train Loss: 12.0673 Acc: 0.8125
# val Loss: 4.3496 Acc: 0.8750
#
# Epoch 3/29
# ----------
# train Loss: 7.7752 Acc: 0.9062
# val Loss: 3.4683 Acc: 0.8750
#
# Epoch 4/29
# ----------
# train Loss: 12.7233 Acc: 0.7500
# val Loss: 2.2672 Acc: 1.0000
#
# Epoch 5/29
# ----------
# train Loss: 8.0122 Acc: 0.9062
# val Loss: 4.4691 Acc: 0.8125
#
# Epoch 6/29
# ----------
# train Loss: 5.3232 Acc: 0.9375
# val Loss: 2.0823 Acc: 1.0000
#
# Epoch 7/29
# ----------
# train Loss: 9.9521 Acc: 0.8438
# val Loss: 1.8454 Acc: 1.0000
#
# Epoch 8/29
# ----------
# train Loss: 4.5632 Acc: 0.9688
# val Loss: 1.7674 Acc: 1.0000
#
# Epoch 9/29
# ----------
# train Loss: 8.3630 Acc: 0.8750
# val Loss: 3.4229 Acc: 0.8750
#
# Epoch 10/29
# ----------
# train Loss: 7.6328 Acc: 0.8750
# val Loss: 3.2018 Acc: 0.8125
#
# Epoch 11/29
# ----------
# train Loss: 5.9164 Acc: 0.9375
# val Loss: 3.6037 Acc: 0.8125
#
# Epoch 12/29
# ----------
# train Loss: 6.9942 Acc: 0.9062
# val Loss: 2.2033 Acc: 1.0000
#
# Epoch 13/29
# ----------
# train Loss: 4.1259 Acc: 0.9688
# val Loss: 1.9272 Acc: 1.0000
#
# Epoch 14/29
# ----------
# train Loss: 5.2824 Acc: 0.9688
# val Loss: 2.7152 Acc: 0.8750
#
# Epoch 15/29
# ----------
# train Loss: 4.1461 Acc: 1.0000
# val Loss: 2.4719 Acc: 0.9375
#
# Epoch 16/29
# ----------
# train Loss: 8.6131 Acc: 0.8750
# val Loss: 2.6828 Acc: 0.8750
#
# Epoch 17/29
# ----------
# train Loss: 6.1818 Acc: 0.9688
# val Loss: 1.8152 Acc: 1.0000
#
# Epoch 18/29
# ----------
# train Loss: 11.7908 Acc: 0.8125
# val Loss: 1.8308 Acc: 1.0000
#
# Epoch 19/29
# ----------
# train Loss: 7.5515 Acc: 0.9375
# val Loss: 2.1884 Acc: 1.0000
#
# Epoch 20/29
# ----------
# train Loss: 15.8672 Acc: 0.7500
# val Loss: 2.8159 Acc: 0.8750
#
# Epoch 21/29
# ----------
# train Loss: 5.0051 Acc: 0.9375
# val Loss: 1.9677 Acc: 1.0000
#
# Epoch 22/29
# ----------
# train Loss: 4.4153 Acc: 0.9688
# val Loss: 2.7468 Acc: 0.8750
#
# Epoch 23/29
# ----------
# train Loss: 3.4394 Acc: 1.0000
# val Loss: 2.6421 Acc: 0.8750
#
# Epoch 24/29
# ----------
# train Loss: 5.3588 Acc: 0.9688
# val Loss: 1.9838 Acc: 1.0000
#
# Epoch 25/29
# ----------
# train Loss: 4.6702 Acc: 0.9688
# val Loss: 1.9944 Acc: 1.0000
#
# Epoch 26/29
# ----------
# train Loss: 6.8093 Acc: 0.9375
# val Loss: 3.6425 Acc: 0.8125
#
# Epoch 27/29
# ----------
# train Loss: 9.4010 Acc: 0.8750
# val Loss: 2.8744 Acc: 0.8750
#
# Epoch 28/29
# ----------
# train Loss: 6.1112 Acc: 0.9062
# val Loss: 2.1074 Acc: 1.0000
#
# Epoch 29/29
# ----------
# train Loss: 12.0997 Acc: 0.8438
# val Loss: 2.4563 Acc: 1.0000
#
# Training complete in 19m 30s
# Best val Acc: 1.000000

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
visualize_model_predictions(
    model_conv,
    img_path='/content/data/train/normal/1.jpg'
)

plt.ioff()
plt.show()
